# %% [markdown]
# <h2>Data Exploration of Crime Data by US State</h2>

# %% [markdown]
# <h4>Input Variables</h4>
#
# <ul>
# <li>population density</li>
# <li>gun ownership</li>
# <li>household income</li>
# <li>education</li>
# <li>suicide rate</li>
# <li>incarceration rate</li>
# </ul>

# %% [markdown]
# <h4>Output Variables</h4>
# <ul>
# <li>violent crime rate</li>
# <li>murder rate</li>
# <li>gun murder rate</li>
# <li>suicide rate</li>
# </ul>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <a href="http://en.wikipedia.org/wiki/Gun_violence_in_the_United_States_by_state">Gun Violence in the US by State</a>

# %%
guns = pd.read_csv("data/guns.csv")
guns = guns[guns.state != 'District of Columbia']

# %% [markdown]
# <a href="http://en.wikipedia.org/wiki/List_of_U.S._states_by_income">List of US States by Income</a>

# %%
# DC already removed
income = pd.read_csv('data/household_income_2010.txt')
combined = guns.merge(income[['state', 'income']], on='state')

# %% [markdown]
# <a href="http://en.wikipedia.org/wiki/List_of_U.S._states_by_educational_attainment">List of US States by Educational Attainment</a>

# %%
# DC already removed
education = pd.read_csv('data/education.csv')
combined = combined.merge(education[['state', 'high_school', 'bachelors', 'advanced']], on='state')

# %% [markdown]
# <a href="http://usatoday30.usatoday.com/news/health/2007-11-28-depression-suicide-numbers_N.htm">Depression Suicide Numbers</a>

# %%
suicide = pd.read_csv('data/suicide.csv')
combined = combined.merge(suicide[['state', 'suicide_rate']], on='state')

# %% [markdown]
# <a href="http://en.wikipedia.org/wiki/List_of_U.S._states_by_incarceration_rate">List of US States by Incarceration</a>

# %%
incarceration = pd.read_csv('data/incarceration.csv')
combined = combined.merge(incarceration[['state','incarceration_rate']], on='state')

# %% [markdown]
# <a href="https://www.census.gov/statab/ranks/rank21.html">Violent Crimes per US State</a>

# %%
violence = pd.read_csv('data/violence.csv')
combined = combined.merge(violence[['state','violent_crime_rate']], on='state')

# %% [markdown]
# <a href="http://en.wikipedia.org/wiki/List_of_U.S._states_by_poverty_rate">List of US States by Poverty Rate</a>

# %%
poverty = pd.read_csv('data/poverty.csv')
combined = combined.merge(poverty[['state','poverty_rate']], on='state')

# %%
print combined.columns
combined.corr()
# Out:
# Index([u'state', u'population', u'population_density', u'murders', u'gun_murders', u'gun_ownership', u'murder_rate', u'gun_murder_rate', u'income', u'high_school', u'bachelors', u'advanced', u'suicide_rate', u'incarceration_rate', u'violent_crime_rate'], dtype='object')

# %%
primary_cols = ['population_density', 'gun_ownership', 'murder_rate', 'income', 'high_school', 'suicide_rate', 
                'incarceration_rate', 'violent_crime_rate', 'poverty_rate']

# %%
# %matplotlib inline
import seaborn as sns
sns.pairplot(combined[primary_cols])

# %%
import sklearn.linear_model as linear_model
import numpy as np
import matplotlib.pyplot as plt

#
# Fit X and Y using linear regression.  Then create scatter plot with predicted regression line and data points.
#
def fit_and_plot(x, y, xlim):
    
    # Create linear regression object
    regr = linear_model.LinearRegression()
    regr.fit(x, y)
    print "residuals", regr.residues_
    print "Coefficients: \n", regr.coef_

    # The mean square error
    print("Residual sum of squares: %.2f" % np.mean((regr.predict(x) - y) ** 2))
    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % regr.score(x, y))
    print "intercept", regr.intercept_

    plt.scatter(x, y, color='black', s=1)
    plt.plot(x, regr.predict(x), color='blue', linewidth=3)
    plt.xlim(xlim)
    plt.show()
    
#
# Fit and plot DataFrame columns.
#
def fit_and_plot_cols(x_col, y_col, xlim):
    fit_and_plot(x_col.values.reshape(-1,1), y_col.values)

# %%
fit = smf.ols('gun_murder_rate ~ population_density', data=guns).fit()
print fit.pvalues
print fit.summary()
# Out:
# Intercept             1.615177e-11
# population_density    2.938919e-01
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        gun_murder_rate   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.126
# Date:                Thu, 11 Jun 2015   Prob (F-statistic):              0.294
# Time:                        16:22:32   Log-Likelihood:                -90.516
# No. Observations:                  50   AIC:                             185.0
# Df Residuals:                      48   BIC:                             188.9
# Df Model:                           1
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept              2.3479      0.268      8.758      0.000         1.809     2.887
# population_density     0.0009      0.001      1.061      0.294        -0.001     0.003
# ==============================================================================
# Omnibus:                       10.217   Durbin-Watson:                   2.400
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.144
# Skew:                           0.871   Prob(JB):                      0.00627
# Kurtosis:                       4.354   Cond. No.                         408.
# ==============================================================================

# %%
fit = smf.ols('gun_murder_rate ~ gun_ownership', data=guns).fit()
print fit.pvalues
print fit.summary()
# Out:
# Intercept        0.000034
# gun_ownership    0.475355
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        gun_murder_rate   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.5176
# Date:                Thu, 11 Jun 2015   Prob (F-statistic):              0.475
# Time:                        16:22:45   Log-Likelihood:                -90.827
# No. Observations:                  50   AIC:                             185.7
# Df Residuals:                      48   BIC:                             189.5
# Df Model:                           1
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         2.9594      0.647      4.571      0.000         1.658     4.261
# gun_ownership    -0.0117      0.016     -0.719      0.475        -0.044     0.021
# ==============================================================================
# Omnibus:                        9.615   Durbin-Watson:                   2.365
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                9.416
# Skew:                           0.825   Prob(JB):                      0.00902
# Kurtosis:                       4.341   Cond. No.                         120.
# ==============================================================================

# %%
fit = smf.ols('gun_murder_rate ~ gun_ownership + population_density', data=guns).fit()
print fit.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        gun_murder_rate   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                 -0.018
# Method:                 Least Squares   F-statistic:                    0.5555
# Date:                Tue, 09 Jun 2015   Prob (F-statistic):              0.578
# Time:                        17:58:21   Log-Likelihood:                -90.511
# No. Observations:                  50   AIC:                             187.0
# Df Residuals:                      47   BIC:                             192.8
# Df Model:                           2
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept              2.2502      1.124      2.002      0.051        -0.011     4.512
# gun_ownership          0.0022      0.024      0.090      0.929        -0.047     0.051
# population_density     0.0010      0.001      0.773      0.443        -0.002     0.003
# ==============================================================================
# Omnibus:                       10.138   Durbin-Watson:                   2.403
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.011
# Skew:                           0.870   Prob(JB):                      0.00670
# Kurtosis:                       4.333   Cond. No.                     1.69e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.69e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
fit = smf.ols('murder_rate ~ population_density', data=guns).fit()
print fit.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            murder_rate   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9515
# Date:                Thu, 11 Jun 2015   Prob (F-statistic):              0.334
# Time:                        16:22:53   Log-Likelihood:                -101.57
# No. Observations:                  50   AIC:                             207.1
# Df Residuals:                      48   BIC:                             211.0
# Df Model:                           1
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept              3.6427      0.334     10.893      0.000         2.970     4.315
# population_density     0.0010      0.001      0.975      0.334        -0.001     0.003
# ==============================================================================
# Omnibus:                        3.571   Durbin-Watson:                   2.377
# Prob(Omnibus):                  0.168   Jarque-Bera (JB):                2.783
# Skew:                           0.570   Prob(JB):                        0.249
# Kurtosis:                       3.196   Cond. No.                         408.
# ==============================================================================

# %%
x = guns['population_density'].values.reshape(-1,1)
y = guns['gun_murder_rate'].values

fit_and_plot(x, y, (0, 2000))
# Out:
# residuals 109.373753907
# Coefficients:
# [ 0.00087592]
# Residual sum of squares: 2.19
# Variance score: 0.02
# intercept 2.34789845531

# %%
x = guns['gun_ownership'].values.reshape(-1,1)
y = guns['gun_murder_rate'].values

fit_and_plot(x, y, (0, 100))
# Out:
# residuals 110.745787399
# Coefficients:
# [-0.0116814]
# Residual sum of squares: 2.21
# Variance score: 0.01
# intercept 2.95936071248

# %%
x = guns['population_density'].values.reshape(-1,1)
y = guns['gun_murder_rate'].values

fit_and_plot(x, y, (0, 500))
# Out:
# residuals 109.373753907
# Coefficients:
# [ 0.00087592]
# Residual sum of squares: 2.19
# Variance score: 0.02
# intercept 2.34789845531

# %%
plt.scatter(guns['income'], guns['murder_rate'])

# %%
fit = smf.ols('murder_rate ~ income', data=guns).fit()
print fit.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            murder_rate   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     1.662
# Date:                Tue, 09 Jun 2015   Prob (F-statistic):              0.204
# Time:                        18:11:23   Log-Likelihood:                -99.552
# No. Observations:                  49   AIC:                             203.1
# Df Residuals:                      47   BIC:                             206.9
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      5.8250      1.576      3.695      0.001         2.654     8.996
# income     -3.947e-05   3.06e-05     -1.289      0.204        -0.000  2.21e-05
# ==============================================================================
# Omnibus:                        2.451   Durbin-Watson:                   2.365
# Prob(Omnibus):                  0.294   Jarque-Bera (JB):                1.926
# Skew:                           0.485   Prob(JB):                        0.382
# Kurtosis:                       3.026   Cond. No.                     3.02e+05
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.02e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# <a href="http://stackoverflow.com/questions/7586384/color-states-with-pythons-matplotlib-basemap">Color States with Python's Matplotlib Basemap</a>

# %% [markdown]
# <h2>Linear Regression Analysis of Murder Rate by US State</h2>

# %% [markdown]
# <h4>Input Variables</h4>
#
# <ul>
# <li>population density</li>
# <li>household income</li>
# <li>poverty rate</li>
# <li>education</li>
# <li>suicide rate</li>
# <li>incarceration rate</li>
# </ul>

# %% [markdown]
# <h4>Output Variable</h4>
# <ul>
# <li>murder rate</li>
# </ul>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %% [markdown]
# <a href="http://en.wikipedia.org/wiki/Gun_violence_in_the_United_States_by_state">Gun Violence in the US by State</a>

# %%
guns = pd.read_csv("data/guns.csv")
guns = guns[guns.state != 'District of Columbia']

# %% [markdown]
# <a href="http://en.wikipedia.org/wiki/List_of_U.S._states_by_income">List of US States by Income</a>

# %%
# DC already removed
income = pd.read_csv('data/household_income_2010.txt')
combined = guns.merge(income[['state', 'income']], on='state')

# %% [markdown]
# <a href="http://en.wikipedia.org/wiki/List_of_U.S._states_by_educational_attainment">List of US States by Educational Attainment</a>

# %%
# DC already removed
education = pd.read_csv('data/education.csv')
combined = combined.merge(education[['state', 'high_school', 'bachelors', 'advanced']], on='state')
combined['no_high_school'] = 100. - combined['high_school']

# %% [markdown]
# <a href="http://usatoday30.usatoday.com/news/health/2007-11-28-depression-suicide-numbers_N.htm">Depression Suicide Numbers</a>

# %%
suicide = pd.read_csv('data/suicide.csv')
combined = combined.merge(suicide[['state', 'suicide_rate']], on='state')

# %% [markdown]
# <a href="http://en.wikipedia.org/wiki/List_of_U.S._states_by_incarceration_rate">List of US States by Incarceration</a>

# %%
incarceration = pd.read_csv('data/incarceration.csv')
combined = combined.merge(incarceration[['state','incarceration_rate']], on='state')

# %% [markdown]
# <a href="https://www.census.gov/statab/ranks/rank21.html">Violent Crimes per US State</a>

# %%
violence = pd.read_csv('data/violence.csv')
combined = combined.merge(violence[['state','violent_crime_rate']], on='state')

# %% [markdown]
# <a href="http://en.wikipedia.org/wiki/List_of_U.S._states_by_poverty_rate">List of US States by Poverty Rate</a>

# %%
poverty = pd.read_csv('data/poverty.csv')
combined = combined.merge(poverty[['state','poverty_rate']], on='state')

# %%
primary_cols = ['murder_rate', 'population_density', 'high_school', 'suicide_rate', 'incarceration_rate', 'poverty_rate', 
                'income', 'gun_ownership']

# %%
print combined.columns
combined[primary_cols].corr()
# Out:
# Index([u'state', u'population', u'population_density', u'murders', u'gun_murders', u'gun_ownership', u'murder_rate', u'gun_murder_rate', u'income', u'high_school', u'bachelors', u'advanced', u'suicide_rate', u'incarceration_rate', u'violent_crime_rate', u'poverty_rate'], dtype='object')
#                     murder_rate  population_density  high_school  \
# murder_rate            1.000000            0.139420    -0.669136
# population_density     0.139420            1.000000    -0.046725
# high_school           -0.669136           -0.046725     1.000000
# suicide_rate          -0.081453           -0.641630     0.115563
# incarceration_rate     0.655537           -0.270220    -0.626972
# poverty_rate           0.515520           -0.289172    -0.766861
# income                -0.190506            0.496774     0.446929
# gun_ownership         -0.119836           -0.739535     0.015967
#
#                     suicide_rate  incarceration_rate  poverty_rate    income  \
# murder_rate            -0.081453            0.655537      0.515520 -0.190506
# population_density     -0.641630           -0.270220     -0.289172  0.496774
# high_school             0.115563           -0.626972     -0.766861  0.446929
# suicide_rate            1.000000            0.203124      0.157947 -0.293510
# incarceration_rate      0.203124            1.000000      0.657218 -0.530396
# poverty_rate            0.157947            0.657218      1.000000 -0.704510
# income                 -0.293510           -0.530396     -0.704510  1.000000
# gun_ownership           0.662998            0.341129      0.349344 -0.560928
#
#                     gun_ownership
# murder_rate             -0.119836
# population_density      -0.739535
# high_school              0.015967
# suicide_rate             0.662998
# incarceration_rate       0.341129
# poverty_rate             0.349344
# income                  -0.560928
# gun_ownership            1.000000

# %%
# %matplotlib inline
import seaborn as sns
sns.pairplot(combined[primary_cols])
plt.savefig('corr.png')

# %%
import sklearn.linear_model as linear_model
import numpy as np
import matplotlib.pyplot as plt

#
# Fit and plot DataFrame columns.
#
def fit_and_plot(df, title, x_col_name, y_col_name, **kwargs):
    
    # Get column data for plot
    x = df[x_col_name].values.reshape(-1,1)
    y = df[y_col_name].values
    
    # Perform OLS fit
    ols_fit = smf.ols(y_col_name + ' ~ ' + y_col_name, data=df).fit()
    print ols_fit.pvalues
    print ols_fit.summary()
    
    # Create linear regression model and perform fit
    regr = linear_model.LinearRegression()
    regr.fit(x, y)
    print "residuals", regr.residues_
    print "Coefficients: \n", regr.coef_

    # The mean square error
    print("Residual sum of squares: %.2f" % np.mean((regr.predict(x) - y) ** 2))
    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % regr.score(x, y))
    print "intercept", regr.intercept_

    plt.axes().grid(b=False)
    plt.axes(axisbg='white')    
    plt.axhline(0, color='black')
    plt.axvline(0, color='black')
    plt.scatter(x, y, color='blue', s=8, alpha=0.8)
    plt.plot(x, regr.predict(x), color='red', linewidth=1, alpha=1.0)
    plt.xlim(xmin=0)
    plt.ylim(ymin=0)
        
    plt.suptitle(title, fontsize=20)
    plt.xlabel(x_col_name.replace('_', ' '), fontsize=12)
    plt.ylabel(y_col_name.replace('_', ' '), fontsize=12)

# %%
fit_and_plot(combined, 'Population Density vs Murder Rate', 'population_density', 'murder_rate')
# Out:
# Intercept      0.001415
# murder_rate    0.000000
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            murder_rate   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.696e+32
# Date:                Sun, 14 Jun 2015   Prob (F-statistic):               0.00
# Time:                        01:50:43   Log-Likelihood:                 1656.4
# No. Observations:                  50   AIC:                            -3309.
# Df Residuals:                      48   BIC:                            -3305.
# Df Model:                           1
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept    -1.11e-15   3.28e-16     -3.388      0.001     -1.77e-15 -4.51e-16
# murder_rate     1.0000   7.68e-17    1.3e+16      0.000         1.000     1.000
# ==============================================================================
# Omnibus:                       49.365   Durbin-Watson:                   0.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              215.671
# Skew:                           2.634   Prob(JB):                     1.47e-47
# Kurtosis:                      11.704   Cond. No.                         10.2
# ==============================================================================
# residuals 170.166762326
# Coefficients:
# [ 0.00100425]
# Residual sum of squares: 3.40
# Variance score: 0.02
# intercept 3.64268546025

# %%
fit_and_plot(combined, 'Income vs Murder Rate', 'income', 'murder_rate')
plt.xlim((35000, 75000))
plt.axvline(35000, color='black')
# Out:
# Intercept      0.001415
# murder_rate    0.000000
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            murder_rate   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.696e+32
# Date:                Sun, 14 Jun 2015   Prob (F-statistic):               0.00
# Time:                        00:54:16   Log-Likelihood:                 1656.4
# No. Observations:                  50   AIC:                            -3309.
# Df Residuals:                      48   BIC:                            -3305.
# Df Model:                           1
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept    -1.11e-15   3.28e-16     -3.388      0.001     -1.77e-15 -4.51e-16
# murder_rate     1.0000   7.68e-17    1.3e+16      0.000         1.000     1.000
# ==============================================================================
# Omnibus:                       49.365   Durbin-Watson:                   0.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              215.671
# Skew:                           2.634   Prob(JB):                     1.47e-47
# Kurtosis:                      11.704   Cond. No.                         10.2
# ==============================================================================
# residuals 167.241799286
# Coefficients:
# [ -4.05336363e-05]
# Residual sum of squares: 3.34
# Variance score: 0.04
# intercept 5.89076852181

# %%
fit_and_plot(combined, 'Poverty Rate vs Murder Rate', 'poverty_rate', 'murder_rate')
plt.xlim((5, 22))
plt.axvline(5, color='black')
# Out:
# Intercept      0.001415
# murder_rate    0.000000
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            murder_rate   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.696e+32
# Date:                Sun, 14 Jun 2015   Prob (F-statistic):               0.00
# Time:                        01:01:58   Log-Likelihood:                 1656.4
# No. Observations:                  50   AIC:                            -3309.
# Df Residuals:                      48   BIC:                            -3305.
# Df Model:                           1
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept    -1.11e-15   3.28e-16     -3.388      0.001     -1.77e-15 -4.51e-16
# murder_rate     1.0000   7.68e-17    1.3e+16      0.000         1.000     1.000
# ==============================================================================
# Omnibus:                       49.365   Durbin-Watson:                   0.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              215.671
# Skew:                           2.634   Prob(JB):                     1.47e-47
# Kurtosis:                      11.704   Cond. No.                         10.2
# ==============================================================================
# residuals 127.419807051
# Coefficients:
# [ 0.31876058]
# Residual sum of squares: 2.55
# Variance score: 0.27
# intercept -0.0303909347793

# %%
fit_and_plot(combined, 'Percentage Graduated HS vs Murder Rate', 'high_school', 'murder_rate')
plt.xlim((79,93))
plt.axvline(79, color='black')
# Out:
# Intercept      0.001415
# murder_rate    0.000000
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            murder_rate   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.696e+32
# Date:                Sun, 14 Jun 2015   Prob (F-statistic):               0.00
# Time:                        01:58:55   Log-Likelihood:                 1656.4
# No. Observations:                  50   AIC:                            -3309.
# Df Residuals:                      48   BIC:                            -3305.
# Df Model:                           1
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept    -1.11e-15   3.28e-16     -3.388      0.001     -1.77e-15 -4.51e-16
# murder_rate     1.0000   7.68e-17    1.3e+16      0.000         1.000     1.000
# ==============================================================================
# Omnibus:                       49.365   Durbin-Watson:                   0.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              215.671
# Skew:                           2.634   Prob(JB):                     1.47e-47
# Kurtosis:                      11.704   Cond. No.                         10.2
# ==============================================================================
# residuals 95.8387727487
# Coefficients:
# [-0.36907788]
# Residual sum of squares: 1.92
# Variance score: 0.45
# intercept 35.9032714709

# %%
fit_and_plot(combined, 'Incarceration Rate vs Murder Rate', 'incarceration_rate', 'murder_rate')
plt.xlim((100,950))
plt.axvline(100, color='black')
plt.savefig('incarceration.png')
# Out:
# Intercept      0.001415
# murder_rate    0.000000
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            murder_rate   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.696e+32
# Date:                Sun, 14 Jun 2015   Prob (F-statistic):               0.00
# Time:                        01:17:01   Log-Likelihood:                 1656.4
# No. Observations:                  50   AIC:                            -3309.
# Df Residuals:                      48   BIC:                            -3305.
# Df Model:                           1
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept    -1.11e-15   3.28e-16     -3.388      0.001     -1.77e-15 -4.51e-16
# murder_rate     1.0000   7.68e-17    1.3e+16      0.000         1.000     1.000
# ==============================================================================
# Omnibus:                       49.365   Durbin-Watson:                   0.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              215.671
# Skew:                           2.634   Prob(JB):                     1.47e-47
# Kurtosis:                      11.704   Cond. No.                         10.2
# ==============================================================================
# residuals 98.964934182
# Coefficients:
# [ 0.00844509]
# Residual sum of squares: 1.98
# Variance score: 0.43
# intercept 0.49945917086

# %%
fit_and_plot(combined, 'Suicide Rate vs Murder Rate', 'suicide_rate', 'murder_rate')
plt.xlim((5,25))
plt.axvline(5, color='black')
# Out:
# Intercept      0.001415
# murder_rate    0.000000
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            murder_rate   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.696e+32
# Date:                Sun, 14 Jun 2015   Prob (F-statistic):               0.00
# Time:                        01:23:57   Log-Likelihood:                 1656.4
# No. Observations:                  50   AIC:                            -3309.
# Df Residuals:                      48   BIC:                            -3305.
# Df Model:                           1
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept    -1.11e-15   3.28e-16     -3.388      0.001     -1.77e-15 -4.51e-16
# murder_rate     1.0000   7.68e-17    1.3e+16      0.000         1.000     1.000
# ==============================================================================
# Omnibus:                       49.365   Durbin-Watson:                   0.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              215.671
# Skew:                           2.634   Prob(JB):                     1.47e-47
# Kurtosis:                      11.704   Cond. No.                         10.2
# ==============================================================================
# residuals 172.388645354
# Coefficients:
# [-0.04306383]
# Residual sum of squares: 3.45
# Variance score: 0.01
# intercept 4.37735051119

# %%
fit_and_plot(combined, 'Gun Ownership vs Murder Rate', 'gun_ownership', 'murder_rate')
#plt.xlim((5,25))
#plt.axvline(5, color='black')
# Out:
# Intercept      0.001415
# murder_rate    0.000000
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            murder_rate   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.696e+32
# Date:                Sun, 14 Jun 2015   Prob (F-statistic):               0.00
# Time:                        01:31:45   Log-Likelihood:                 1656.4
# No. Observations:                  50   AIC:                            -3309.
# Df Residuals:                      48   BIC:                            -3305.
# Df Model:                           1
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept    -1.11e-15   3.28e-16     -3.388      0.001     -1.77e-15 -4.51e-16
# murder_rate     1.0000   7.68e-17    1.3e+16      0.000         1.000     1.000
# ==============================================================================
# Omnibus:                       49.365   Durbin-Watson:                   0.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              215.671
# Skew:                           2.634   Prob(JB):                     1.47e-47
# Kurtosis:                      11.704   Cond. No.                         10.2
# ==============================================================================
# residuals 171.04784627
# Coefficients:
# [-0.01687491]
# Residual sum of squares: 3.42
# Variance score: 0.01
# intercept 4.47469899309

# %% [markdown]
# <a href="http://stackoverflow.com/questions/7586384/color-states-with-pythons-matplotlib-basemap">Color States with Python's Matplotlib Basemap</a>

# %%
fit_and_plot(combined, 'Percentage without HS vs Murder Rate', 'no_high_school', 'murder_rate')
plt.xlim((7,21))
plt.axvline(7, color='black')
# Out:
# Intercept      0.001415
# murder_rate    0.000000
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            murder_rate   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.696e+32
# Date:                Sun, 14 Jun 2015   Prob (F-statistic):               0.00
# Time:                        02:00:42   Log-Likelihood:                 1656.4
# No. Observations:                  50   AIC:                            -3309.
# Df Residuals:                      48   BIC:                            -3305.
# Df Model:                           1
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept    -1.11e-15   3.28e-16     -3.388      0.001     -1.77e-15 -4.51e-16
# murder_rate     1.0000   7.68e-17    1.3e+16      0.000         1.000     1.000
# ==============================================================================
# Omnibus:                       49.365   Durbin-Watson:                   0.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              215.671
# Skew:                           2.634   Prob(JB):                     1.47e-47
# Kurtosis:                      11.704   Cond. No.                         10.2
# ==============================================================================
# residuals 95.8387727487
# Coefficients:
# [ 0.36907788]
# Residual sum of squares: 1.92
# Variance score: 0.45
# intercept -1.00451621115

# %%
# Perform OLS fit
ols_fit = smf.ols('murder_rate ~ no_high_school + poverty_rate', data=combined).fit()
print ols_fit.pvalues
print ols_fit.summary()
# Out:
# Intercept         0.251563
# no_high_school    0.000273
# poverty_rate      0.972780
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            murder_rate   R-squared:                       0.448
# Model:                            OLS   Adj. R-squared:                  0.424
# Method:                 Least Squares   F-statistic:                     19.05
# Date:                Sun, 14 Jun 2015   Prob (F-statistic):           8.71e-07
# Time:                        01:53:23   Log-Likelihood:                -87.212
# No. Observations:                  50   AIC:                             180.4
# Df Residuals:                      47   BIC:                             186.2
# Df Model:                           2
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# Intercept         -1.0158      0.875     -1.161      0.252        -2.776     0.745
# no_high_school     0.3666      0.093      3.936      0.000         0.179     0.554
# poverty_rate       0.0036      0.104      0.034      0.973        -0.207     0.214
# ==============================================================================
# Omnibus:                       11.860   Durbin-Watson:                   2.391
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               11.914
# Skew:                           1.063   Prob(JB):                      0.00259
# Kurtosis:                       4.096   Cond. No.                         79.9
# ==============================================================================

# %%
fit_and_plot(combined, 'Violent Crime Rate vs Murder Rate', 'violent_crime_rate', 'murder_rate')
#plt.xlim((7,21))
#plt.axvline(7, color='black')
# Out:
# Intercept      0.001415
# murder_rate    0.000000
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            murder_rate   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.696e+32
# Date:                Sun, 14 Jun 2015   Prob (F-statistic):               0.00
# Time:                        02:08:14   Log-Likelihood:                 1656.4
# No. Observations:                  50   AIC:                            -3309.
# Df Residuals:                      48   BIC:                            -3305.
# Df Model:                           1
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept    -1.11e-15   3.28e-16     -3.388      0.001     -1.77e-15 -4.51e-16
# murder_rate     1.0000   7.68e-17    1.3e+16      0.000         1.000     1.000
# ==============================================================================
# Omnibus:                       49.365   Durbin-Watson:                   0.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              215.671
# Skew:                           2.634   Prob(JB):                     1.47e-47
# Kurtosis:                      11.704   Cond. No.                         10.2
# ==============================================================================
# residuals 60.5646129456
# Coefficients:
# [ 0.00825364]
# Residual sum of squares: 1.21
# Variance score: 0.65
# intercept 0.455345572578

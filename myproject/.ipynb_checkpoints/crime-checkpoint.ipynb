# %% [markdown]
# <h2>Linear Regression Analysis of Murder Rate by US State</h2>

# %% [markdown]
# <h4>Input Variables</h4>
#
# <ul>
# <li>population density</li>
# <li>household income</li>
# <li>poverty rate</li>
# <li>education</li>
# <li>suicide rate</li>
# <li>incarceration rate</li>
# </ul>

# %% [markdown]
# <h4>Output Variable</h4>
# <ul>
# <li>murder rate</li>
# </ul>

# %% [markdown]
# <a href="http://en.wikipedia.org/wiki/Gun_violence_in_the_United_States_by_state">Gun Violence in the US by State</a>

# %% [markdown]
# <a href="http://en.wikipedia.org/wiki/List_of_U.S._states_by_income">List of US States by Income</a>

# %% [markdown]
# <a href="http://en.wikipedia.org/wiki/List_of_U.S._states_by_educational_attainment">List of US States by Educational Attainment</a>

# %% [markdown]
# <a href="http://usatoday30.usatoday.com/news/health/2007-11-28-depression-suicide-numbers_N.htm">Depression Suicide Numbers</a>

# %% [markdown]
# <a href="http://en.wikipedia.org/wiki/List_of_U.S._states_by_incarceration_rate">List of US States by Incarceration</a>

# %% [markdown]
# <a href="https://www.census.gov/statab/ranks/rank21.html">Violent Crimes per US State</a>

# %% [markdown]
# <a href="http://en.wikipedia.org/wiki/List_of_U.S._states_by_poverty_rate">List of US States by Poverty Rate</a>

# %%
"""
All imports listed here.
"""
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import sklearn.linear_model as linear_model
import seaborn as sns
from sklearn.linear_model import Lasso
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge 
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.cross_validation import LeaveOneOut, KFold

# %%
"""
Method for importing text data and concatenating into a single DataFrame.
"""
def load_data():
    guns = pd.read_csv("data/guns.csv")
    guns = guns[guns.state != 'District of Columbia']
    
    income = pd.read_csv('data/household_income_2010.txt')
    combined = guns.merge(income[['state', 'income']], on='state')
    
    education = pd.read_csv('data/education.csv')
    combined = combined.merge(education[['state', 'high_school', 'bachelors', 'advanced']], on='state')
    combined['no_high_school'] = 100. - combined['high_school']
    
    suicide = pd.read_csv('data/suicide.csv')
    combined = combined.merge(suicide[['state', 'suicide_rate']], on='state')
    
    incarceration = pd.read_csv('data/incarceration.csv')
    combined = combined.merge(incarceration[['state','incarceration_rate']], on='state')
    
    violence = pd.read_csv('data/violence.csv')
    combined = combined.merge(violence[['state','violent_crime_rate']], on='state')
    
    poverty = pd.read_csv('data/poverty.csv')
    combined = combined.merge(poverty[['state','poverty_rate']], on='state')
    
    return combined

combined = load_data()

# %%
"""
Primary columns to be used for data analysis including predicted variable and all features.
"""
primary_cols = [
    'murder_rate', 'population_density', 'high_school', 
    'suicide_rate', 'incarceration_rate', 'poverty_rate', 
    'income', 'gun_ownership'
]

feature_cols = [
    'population_density', 'high_school', 'suicide_rate', 
    'incarceration_rate', 'poverty_rate', 'income', 'gun_ownership'
]

# %%
combined[primary_cols].describe()
# Out:
#        murder_rate  population_density  high_school  suicide_rate  \
# count    50.000000           50.000000    50.000000      50.00000
# mean      3.840000          196.479780    86.874000      12.47800
# std       1.881923          261.266788     3.411913       3.55954
# min       1.000000            1.264000    79.900000       6.00000
# 25%       2.125000           44.612500    83.975000      10.65000
# 50%       4.050000          100.335000    87.500000      11.90000
# 75%       5.075000          214.425000    89.800000      14.35000
# max       9.600000         1189.000000    91.800000      23.10000
#
#        incarceration_rate  poverty_rate        income  gun_ownership
# count           50.000000     50.000000     50.000000      50.000000
# mean           395.560000     12.142000  50594.240000      37.612000
# std            146.081213      3.043567   8844.934931      13.364355
# min            148.000000      5.600000  36646.000000       6.700000
# 25%            273.000000     10.025000  44783.500000      31.425000
# 50%            380.500000     11.700000  48290.000000      40.050000
# 75%            458.500000     14.475000  55213.750000      44.050000
# max            847.000000     20.100000  69860.000000      59.700000

# %%
print combined.columns
combined[primary_cols].corr()
# Out:
# Index([u'state', u'population', u'population_density', u'murders', u'gun_murders', u'gun_ownership', u'murder_rate', u'gun_murder_rate', u'income', u'high_school', u'bachelors', u'advanced', u'no_high_school', u'suicide_rate', u'incarceration_rate', u'violent_crime_rate', u'poverty_rate'], dtype='object')
#                     murder_rate  population_density  high_school  \
# murder_rate            1.000000            0.139420    -0.669136
# population_density     0.139420            1.000000    -0.046725
# high_school           -0.669136           -0.046725     1.000000
# suicide_rate          -0.081453           -0.641630     0.115563
# incarceration_rate     0.655537           -0.270220    -0.626972
# poverty_rate           0.515520           -0.289172    -0.766861
# income                -0.190506            0.496774     0.446929
# gun_ownership         -0.119836           -0.739535     0.015967
#
#                     suicide_rate  incarceration_rate  poverty_rate    income  \
# murder_rate            -0.081453            0.655537      0.515520 -0.190506
# population_density     -0.641630           -0.270220     -0.289172  0.496774
# high_school             0.115563           -0.626972     -0.766861  0.446929
# suicide_rate            1.000000            0.203124      0.157947 -0.293510
# incarceration_rate      0.203124            1.000000      0.657218 -0.530396
# poverty_rate            0.157947            0.657218      1.000000 -0.704510
# income                 -0.293510           -0.530396     -0.704510  1.000000
# gun_ownership           0.662998            0.341129      0.349344 -0.560928
#
#                     gun_ownership
# murder_rate             -0.119836
# population_density      -0.739535
# high_school              0.015967
# suicide_rate             0.662998
# incarceration_rate       0.341129
# poverty_rate             0.349344
# income                  -0.560928
# gun_ownership            1.000000

# %%
#sns.pairplot(combined[primary_cols])
#plt.savefig('corr.png')

# %%
sorted = combined[["state", "murder_rate"]].sort(columns=["murder_rate"], ascending=False)
sorted.head()
# Out:
#              state  murder_rate
# 17       Louisiana          9.6
# 19        Maryland          7.3
# 24        Missouri          7.0
# 39  South Carolina          6.1
# 27          Nevada          5.9

# %%
"""
Plot feature on X vs predicted variable on Y for all features of interest.
"""

f, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8)) = plt.subplots(2, 4)

f.set_size_inches(18.5, 10.5)

x_cols = ['population_density', 'high_school', 'suicide_rate', 
          'incarceration_rate', 'poverty_rate', 'income', 'gun_ownership']
axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7]

def plot_ax(ax, x_col_name):
    
    ax.scatter(combined[x_col_name], combined["murder_rate"], s=combined['population']/25000., alpha=0.2)
    x_margin = (combined[x_col_name].max() - combined[x_col_name].min()) * 0.1  
    ax.set_xlim([combined[x_col_name].min() - x_margin, combined[x_col_name].max() + x_margin])
    ax.set_xlabel(x_col_name.replace("_", " "))
    ax.set_axis_bgcolor("white")
        
for a, x in zip(axes, x_cols):
    plot_ax(a, x)
    
ax8.set_axis_bgcolor("white")
    
f.subplots_adjust(hspace=0.5)

# %%
"""
Perform a linear fit of predicted variable vs a single feature and plot the result.
"""
def fit_lin(df, title, x_col_name, y_col_name="murder_rate"):
        
    # Get column data for plot
    x = df[x_col_name].values.reshape(-1,1)
    y = df[y_col_name].values
            
    # Create linear regression model and perform fit
    regr = linear_model.LinearRegression()
    regr.fit(x, y)
    
    print "residuals", regr.residues_
    print "Coefficients: \n", regr.coef_

    # The mean square error
    print("Residual sum of squares: %.2f" % np.mean((regr.predict(x) - y) ** 2))
    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % regr.score(x, y))
    print "intercept", regr.intercept_

    predicted = regr.predict(x)
    truth = df[y_col_name].values
    
    mse = mean_squared_error(truth, predicted)
    mae = mean_absolute_error(truth, predicted)
    
    fig = plt.figure()
    ax = fig.add_subplot(111, axisbg="white")
    
    ax.grid(b=False)
    
    ax.scatter(x, y, color='blue', alpha=0.2, s=df['population']/25000.)
    ax.plot(x, regr.predict(x), color='red', linewidth=1, alpha=1.0)
    ax.annotate("Mean Sq Err = " + str(round(mse, 4)), xy=(0.7, 0.85), xycoords="figure fraction")
    ax.annotate("Mean Ab Err = " + str(round(mae, 4)), xy=(0.7, 0.8), xycoords="figure fraction")
    ax.annotate("Var Score = " + str(round(regr.score(x, y), 4)), xy=(0.7, 0.75), xycoords="figure fraction")
    
    ax.set_xlabel(x_col_name.replace('_', ' '), fontsize=12)
    ax.set_ylabel(y_col_name.replace('_', ' '), fontsize=12)
    
    ax.set_title(title, fontsize=20)
        
    plt.show()

# %%
"""
Perform a polynomial fit of degree 4 using a single feature (function is currently unused).
"""
def fit_poly(df, title, x_col_name, y_col_name="murder_rate", degree=4):

    x = df[x_col_name].values.reshape(-1,1)
    y = df[y_col_name].values.reshape(-1,1)
    
    degree = 4
    est = make_pipeline(PolynomialFeatures(degree), LinearRegression())
    est.fit(x, y)
    
    predicted = est.predict(x)
    truth = df["murder_rate"].values
    
    mse = mean_squared_error(truth, predicted)
    mae = mean_absolute_error(truth, predicted)
    
    x_min = df[x_col_name].min()
    x_max = df[x_col_name].max() 
    x_plot = np.linspace(x_min, x_max, 100)
            
    plt.axes().grid(b=False)
    plt.axes(axisbg='white')    
    
    plt.scatter(x, y, s=df['population']/25000, alpha=0.25)
    plt.plot(x_plot, est.predict(x_plot[:, np.newaxis]), color='red')
    
    ax.annotate("Mean Sq Err = " + str(round(mse, 4)), xy=(0.7, 0.8), xycoords="figure fraction")
    ax.annotate("Mean Ab Err = " + str(round(mae, 4)), xy=(0.7, 0.85), xycoords="figure fraction")
    
    plt.suptitle(title, fontsize=20)
    plt.xlabel(x_col_name.replace('_', ' '), fontsize=12)
    plt.ylabel(y_col_name.replace('_', ' '), fontsize=12)
    plt.show()

# %%
# OLS fit
def fit_ols(df, x_col_name, y_col_name="murder_rate"):
    ols_fit = smf.ols(y_col_name + ' ~ ' + x_col_name, data=df).fit()
    print ols_fit.pvalues
    print ols_fit.summary()

# %%
"""
Perform a polynomial fit of degree 3 with LASSO (L1-norm) constraint of coefficients.
"""
def fit_lasso(df, title, x_col_name, y_col_name="murder_rate", degree=3, alpha=1e-3):
    
    x = df[x_col_name].values.reshape(-1,1)
    y = df[y_col_name].values.reshape(-1,1)
    
    degree = 4
    est = make_pipeline(PolynomialFeatures(degree), Lasso(alpha=alpha, max_iter=1000))
    est.fit(x, y)
    
    predicted = est.predict(x)
    truth = df[y_col_name].values
    
    mse = mean_squared_error(truth, predicted)
    mae = mean_absolute_error(truth, predicted)
        
    x_min = df[x_col_name].min()
    x_max = df[x_col_name].max()
    x_plot = np.linspace(x_min, x_max, 100)
    
    fig = plt.figure()
    ax = fig.add_subplot(111, axisbg="white")
    
    ax.grid(b=False)
    
    ax.scatter(x, y, s=df['population']/25000, alpha=0.25)
    ax.plot(x_plot, est.predict(x_plot[:, np.newaxis]), color='red')
    
    ax.annotate("Mean Sq Err = " + str(round(mse, 4)), xy=(0.7, 0.85), xycoords="figure fraction")
    ax.annotate("Mean Ab Err = " + str(round(mae, 4)), xy=(0.7, 0.8), xycoords="figure fraction")
    ax.annotate("Var Score = " + str(round(est.score(x, y), 4)), xy=(0.7, 0.75), xycoords="figure fraction")
    
    ax.set_title(title, fontsize=20)
    ax.set_xlabel(x_col_name.replace('_', ' '), fontsize=12)
    ax.set_ylabel(y_col_name.replace('_', ' '), fontsize=12)

    plt.show()

# %%
"""
Run LOO cross-validation using a list of features for the regression.
"""
def predict_loo(x_col_names, df, model, y_col_name = "murder_rate"):    
    loo = LeaveOneOut(len(df))
    predicted = []
    n_features = len(x_col_names)
    for train, test in loo:
        x_train = df.iloc[train][x_col_names].values.reshape(-1, n_features)
        y_train = df.iloc[train][y_col_name].values.reshape(-1, 1)
        model.fit(x_train, y_train)        
        x_test = df.iloc[test][x_col_names].values.reshape(-1, n_features)     
        est = model.predict(x_test)
        predicted.extend(est)        
    return predicted

"""
Run LOO cross-validation on a series of features using a list of regression models.
"""
def xval_models(df, x_col_names, models, y_col_name="murder_rate"):
    
    xval_df = pd.DataFrame(columns=["feature", "model", "model_mse", "model_mae", "xval_mse", "xval_mae"])
    
    truth = df[y_col_name].values
    y = df[y_col_name].values.reshape(-1,1)
    for x_col_name in x_col_names:
        x = df[x_col_name].values.reshape(-1,1)
        print "xvalidating", x_col_name
        for model_name, model in models.iteritems():
            
            print "running model", model_name

            # Run LOO x-val on the model.
            xval_predicted = predict_loo([x_col_name], df, model, y_col_name)
            xval_mse = mean_squared_error(truth, xval_predicted)
            xval_mae = mean_absolute_error(truth, xval_predicted)
            print "Cross Val Mean Sq Error = ", xval_mse
            print "Cross Val Mean Abs Error = ", xval_mae
            
            # Fit the and predict using all data points for comparison.
            model.fit(x, y)
            predicted = model.predict(x)
            model_mse = mean_squared_error(truth, predicted)
            model_mae = mean_absolute_error(truth, predicted)
            print "Model Mean Sq Error = ", model_mse
            print "Model Mean Abs Error = ", model_mae
            
            # Append Mean Sq Error and Mean Abs Error to output DF.
            xval_df.loc[len(xval_df)] = [x_col_name, model_name, model_mse, model_mae, xval_mse, xval_mae]
        print
    return xval_df

# %%
def mean_err(df, col_name):
    mean = np.mean(df[col_name])
    errors = 0.
    for murder_rate in df[col_name]:
        errors += abs(mean - murder_rate)
    return errors / float(len(df[col_name]))

mean_err(combined, "murder_rate")
# Out:
# 1.5624

# %%
#, RandomForestRegressor()

models = {
    "Linear Regression": linear_model.LinearRegression(),
    "Polynomial": make_pipeline(PolynomialFeatures(3), Lasso(alpha=1e-3, max_iter=1000))
}

xval_df = xval_models(combined, feature_cols, models)

xval_df
# Out:
# xvalidating population_density
# running model Polynomial
# Cross Val Mean Sq Error =  3.46342453936
# Cross Val Mean Abs Error =  1.49233898565
# Model Mean Sq Error =  2.97994714106
# Model Mean Abs Error =  1.36174802319
# running model Linear Regression
# Cross Val Mean Sq Error =  3.6628870668
# Cross Val Mean Abs Error =  1.63295465779
# Model Mean Sq Error =  3.40333524652
# Model Mean Abs Error =  1.56840100617
#
# xvalidating high_school
# running model Polynomial
# Cross Val Mean Sq Error =  1.90397072134
# Cross Val Mean Abs Error =  0.983709594908
# Model Mean Sq Error =  1.72500091498
# Model Mean Abs Error =  0.936626588027
# running model Linear Regression
# Cross Val Mean Sq Error =  2.08124563429
# Cross Val Mean Abs Error =  1.11582359085
# Model Mean Sq Error =  1.91677545497
# Model Mean Abs Error =  1.06985277767
#
# xvalidating suicide_rate
# running model Polynomial
# Cross Val Mean Sq Error =  3.73176115043
# Cross Val Mean Abs Error =  1.62300161196
# Model Mean Sq Error =  3.35437579268
# Model Mean Abs Error =  1.51920811514
# running model Linear Regression
# Cross Val Mean Sq Error =  3.70480950021
# Cross Val Mean Abs Error =  1.62234664296
# Model Mean Sq Error =  3.44777290709
# Model Mean Abs Error =  1.56011244918
#
# xvalidating incarceration_rate
# running model Polynomial
# Cross Val Mean Sq Error =  2.64738496876
# Cross Val Mean Abs Error =  1.27998293398
# Model Mean Sq Error =  1.89115981485
# Model Mean Abs Error =  1.12811929902
# running model Linear Regression
# Cross Val Mean Sq Error =  2.14617640496
# Cross Val Mean Abs Error =  1.19564250121
# Model Mean Sq Error =  1.97929868364
# Model Mean Abs Error =  1.14698061823
#
# xvalidating poverty_rate
# running model Polynomial
# Cross Val Mean Sq Error =  3.08705782505
# Cross Val Mean Abs Error =  1.41363754859
# Model Mean Sq Error =  2.52590488832
# Model Mean Abs Error =  1.28865242167
# running model Linear Regression
# Cross Val Mean Sq Error =  2.77234889263
# Cross Val Mean Abs Error =  1.32524057904
# Model Mean Sq Error =  2.54839614102
# Model Mean Abs Error =  1.27282927541
#
# xvalidating income
# running model Polynomial
# Cross Val Mean Sq Error =  3.03883113706
# Cross Val Mean Abs Error =  1.40108795258
# Model Mean Sq Error =  2.69564571271
# Model Mean Abs Error =  1.32114254396
# running model Linear Regression
# Cross Val Mean Sq Error =  3.66929413884
# Cross Val Mean Abs Error =  1.59179368618
# Model Mean Sq Error =  3.34483598571
# Model Mean Abs Error =  1.52566878679
#
# xvalidating gun_ownership
# running model Polynomial
# Cross Val Mean Sq Error =  3.55676520348
# Cross Val Mean Abs Error =  1.55330683382
# Model Mean Sq Error =  3.16312411597
# Model Mean Abs Error =  1.45040557081
# running model Linear Regression
# Cross Val Mean Sq Error =  3.68902195359
# Cross Val Mean Abs Error =  1.62179673573
# Model Mean Sq Error =  3.4209569254
# Model Mean Abs Error =  1.55928995972
#                feature              model model_mse  model_mae  xval_mse  \
# 0   population_density         Polynomial  2.979947   1.361748  3.463425
# 1   population_density  Linear Regression  3.403335   1.568401  3.662887
# 2          high_school         Polynomial  1.725001  0.9366266  1.903971
# 3          high_school  Linear Regression  1.916775   1.069853  2.081246
# 4         suicide_rate         Polynomial  3.354376   1.519208  3.731761
# 5         suicide_rate  Linear Regression  3.447773   1.560112   3.70481
# 6   incarceration_rate         Polynomial   1.89116   1.128119  2.647385
# 7   incarceration_rate  Linear Regression  1.979299   1.146981  2.146176
# 8         poverty_rate         Polynomial  2.525905   1.288652  3.087058
# 9         poverty_rate  Linear Regression  2.548396   1.272829  2.772349
# 10              income         Polynomial  2.695646   1.321143  3.038831
# 11              income  Linear Regression  3.344836   1.525669  3.669294
# 12       gun_ownership         Polynomial  3.163124   1.450406  3.556765
# 13       gun_ownership  Linear Regression  3.420957    1.55929  3.689022
#
#      xval_mae
# 0    1.492339
# 1    1.632955
# 2   0.9837096
# 3    1.115824
# 4    1.623002
# 5    1.622347
# 6    1.279983
# 7    1.195643
# 8    1.413638
# 9    1.325241
# 10   1.401088
# 11   1.591794
# 12   1.553307
# 13   1.621797

# %%
#fit_ols(combined, 'population_density')
fit_lin(combined, 'Population Density vs Murder Rate', 'population_density')
#fit_poly(combined, 'Population Density vs Murder Rate', 'population_density')
fit_lasso(combined, 'Population Density vs Murder Rate', 'population_density')
# Out:
# residuals 170.166762326
# Coefficients:
# [ 0.00100425]
# Residual sum of squares: 3.40
# Variance score: 0.02
# intercept 3.64268546025

# %%
#fit_lin(combined, 'Income vs Murder Rate', 'income')
#fit_poly(combined, 'Income vs Murder Rate', 'income')
#fit_lasso(combined, 'Income vs Murder Rate', 'income')

# %%
fit_lin(combined, 'Poverty Rate vs Murder Rate', 'poverty_rate')
#fit_poly(combined, 'Poverty Rate vs Murder Rate', 'poverty_rate')
fit_lasso(combined, 'Poverty Rate vs Murder Rate', 'poverty_rate')
# Out:
# residuals 127.419807051
# Coefficients:
# [ 0.31876058]
# Residual sum of squares: 2.55
# Variance score: 0.27
# intercept -0.0303909347793

# %%
fit_lin(combined, 'Percentage Graduated HS vs Murder Rate', 'high_school')
#fit_poly(combined, 'Percentage Graduated HS vs Murder Rate', 'high_school')
fit_lasso(combined, 'Percentage Graduated HS vs Murder Rate', 'high_school')
# Out:
# residuals 95.8387727487
# Coefficients:
# [-0.36907788]
# Residual sum of squares: 1.92
# Variance score: 0.45
# intercept 35.9032714709

# %%
fit_lin(combined, 'Incarceration Rate vs Murder Rate', 'incarceration_rate')
#plt.savefig('incarceration.png')
#fit_poly(combined, 'Incarceration Rate vs Murder Rate', 'incarceration_rate')
fit_lasso(combined, 'Incarceration Rate vs Murder Rate', 'incarceration_rate')
# Out:
# residuals 98.964934182
# Coefficients:
# [ 0.00844509]
# Residual sum of squares: 1.98
# Variance score: 0.43
# intercept 0.49945917086

# %%
fit_lin(combined, 'Suicide Rate vs Murder Rate', 'suicide_rate')
#fit_poly(combined, 'Suicide Rate vs Murder Rate', 'suicide_rate')
fit_lasso(combined, 'Suicide Rate vs Murder Rate', 'suicide_rate')
# Out:
# residuals 172.388645354
# Coefficients:
# [-0.04306383]
# Residual sum of squares: 3.45
# Variance score: 0.01
# intercept 4.37735051119

# %%
fit_lin(combined, 'Gun Ownership vs Murder Rate', 'gun_ownership')
#fit_poly(combined, 'Gun Ownership vs Murder Rate', 'gun_ownership')
fit_lasso(combined, 'Gun Ownership vs Murder Rate', 'gun_ownership')
# Out:
# residuals 171.04784627
# Coefficients:
# [-0.01687491]
# Residual sum of squares: 3.42
# Variance score: 0.01
# intercept 4.47469899309

# %%
fit_lin(combined, 'Percentage without HS vs Murder Rate', 'no_high_school')
#fit_poly(combined, 'Percentage without HS vs Murder Rate', 'no_high_school')
fit_lasso(combined, 'Percentage without HS vs Murder Rate', 'no_high_school')
# Out:
# residuals 95.8387727487
# Coefficients:
# [ 0.36907788]
# Residual sum of squares: 1.92
# Variance score: 0.45
# intercept -1.00451621115

# %%
fit_lin(combined, 'Violent Crime Rate vs Murder Rate', 'violent_crime_rate')
#fit_poly(combined, 'Violent Crime Rate vs Murder Rate', 'violent_crime_rate')
fit_lasso(combined, 'Violent Crime Rate vs Murder Rate', 'violent_crime_rate')
# Out:
# residuals 60.5646129456
# Coefficients:
# [ 0.00825364]
# Residual sum of squares: 1.21
# Variance score: 0.65
# intercept 0.455345572578

# %%
# sum(actual_value - mean)^2) / total_n

# %%
fit_lin(combined, "Gun Ownership vs Suicide Rate", "gun_ownership", y_col_name="suicide_rate")
fit_lasso(combined, "Gun Ownership vs Suicide Rate", "gun_ownership", y_col_name="suicide_rate")
fit_lin(combined, "Population Density vs Suicide Rate", "gun_ownership", y_col_name="population_density")
fit_lasso(combined, "Population Density vs Suicide Rate", "gun_ownership", y_col_name="population_density")
# Out:
# residuals 347.942736531
# Coefficients:
# [ 0.17658677]
# Residual sum of squares: 6.96
# Variance score: 0.44
# intercept 5.83621825026
# residuals 1515470.00626
# Coefficients:
# [-14.45755381]
# Residual sum of squares: 30309.40
# Variance score: 0.55
# intercept 740.25729383

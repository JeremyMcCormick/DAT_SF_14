# %%
import pandas as pd

# %% [raw]
# TODO: add in...
#
# http://en.wikipedia.org/wiki/Number_of_guns_per_capita_by_country
#
# http://en.wikipedia.org/wiki/List_of_countries_by_intentional_homicide_rate
#
# income inequality
#
# crime rates in rich countries vs gun ownership
#
# median household income
# http://en.wikipedia.org/wiki/Median_household_income
#
# list of countries by firearm related death rate
# http://en.wikipedia.org/wiki/List_of_countries_by_firearm-related_death_rate

# %%
# http://en.wikipedia.org/wiki/Gun_violence_in_the_United_States_by_state
guns = pd.read_csv("data/guns.txt")
print guns
# Out:
#                    state  population  population_density  murders  \
# 0                Alabama     4779736              94.650      199
# 1                 Alaska      710231               1.264       31
# 2                Arizona     6392017              57.050      352
# 3               Arkansas     2915918              56.430      130
# 4             California    37253956             244.200     1811
# 5               Colorado     5029196              49.330      117
# 6            Connecticut     3574097             741.400      131
# 7               Delaware      897934             470.700       48
# 8   District of Columbia      601723           10298.000      131
# 9                Florida    19687653             360.200      987
# 10               Georgia     9920000             172.500      527
# 11                Hawaii     1360301             216.800       24
# 12                 Idaho     1567582              19.500       21
# 13              Illinois    12830632             231.900      453
# 14               Indiana     6483802             182.500      198
# 15                  Iowa     3046355              54.810       38
# 16                Kansas     2853118              35.090      100
# 17              Kentucky     4339367             110.000      180
# 18             Louisiana     4533372             105.000      437
# 19                 Maine     1328361              43.040       24
# 20              Maryland     5773552             606.200      424
# 21         Massachusetts     6547629             852.100      209
# 22              Michigan     9883640             174.800      558
# 23             Minnesota     5303925              67.140       91
# 24           Mississippi     2967297              63.500      165
# 25              Missouri     5988927              87.260      419
# 26               Montana      989415               6.858       21
# 27              Nebraska     1826341              23.970       51
# 28                Nevada     2700551              24.800      158
# 29         New Hampshire     1316470             147.000       13
# 30            New Jersey     8791894            1189.000      363
# 31            New Mexico     2059179              17.160      118
# 32              New York    19378102             415.300      860
# 33       Northo Carolina     9535483             200.600      445
# 34          North Dakota      672591               9.916        9
# 35                  Ohio    11536504             282.500      460
# 36              Oklahoma     3751351              55.220      188
# 37                Oregon     3831074              40.330       78
# 38          Pennsylvania    12702379             285.300      646
# 39          Rhode Island     1052567            1006.000       29
# 40        South Carolina     4625364             157.100      280
# 41          South Dakota      814180              10.860       14
# 42             Tennessee     6346105             156.600      356
# 43                 Texas    25145561              98.070     1246
# 44                  Utah     2763885              34.300       52
# 45               Vermont      625741              67.730        7
# 46              Virginia     8001024             207.300      369
# 47            Washington     6724540             102.600      151
# 48         West Virginia     1852994              77.060       55
# 49             Wisconsin     5686986             105.200      151
# 50               Wyoming      563626               5.851        8
#
#     gun_murders  gun_ownership  murder_rate  gun_murder_rate
# 0           135           51.7          4.2              2.8
# 1            19           57.8          4.4              2.7
# 2           232           31.1          5.5              3.6
# 3            93           55.3          4.5              3.2
# 4          1257           21.3          4.9              3.4
# 5            65           34.7          2.3              1.3
# 6            97           16.7          3.7              2.7
# 7            38           25.5          5.3              4.2
# 8            99            3.6         21.8             16.5
# 9           669           24.5          5.0              3.9
# 10          376           40.3          5.3              3.8
# 11            7            6.7          1.8              0.5
# 12           12           55.3          1.3              0.8
# 13          364           20.2          3.5              2.8
# 14          142           39.1          3.1              2.2
# 15           21           42.9          1.2              0.7
# 16           63           42.1          3.5              2.2
# 17          116           47.7          4.5              2.7
# 18          351           44.1          9.6              7.7
# 19           11           40.5          1.8              0.8
# 20          293           21.3          7.3              5.1
# 21          118           12.6          3.2              1.8
# 22          413           38.4          5.6              4.2
# 23           53           41.7          1.7              1.0
# 24          120           55.3          5.6              4.0
# 25          321           41.7          7.0              5.4
# 26           12           57.7          2.1              1.2
# 27           32           38.6          2.8              1.8
# 28           84           33.8          5.9              3.1
# 29            5           30.0          1.0              0.4
# 30          246           12.3          4.1              2.8
# 31           67           34.8          5.7              3.3
# 32          517           18.0          4.4              2.7
# 33          286           41.3          4.7              3.0
# 34            4           50.7          1.3              0.6
# 35          310           32.4          4.0              2.7
# 36          111           42.9          5.0              3.0
# 37           36           39.8          2.0              0.9
# 38          457           34.7          5.1              3.6
# 39           16           12.8          2.8              1.5
# 40          207           42.3          6.1              4.5
# 41            8           56.6          1.7              1.0
# 42          219           43.9          5.6              3.5
# 43          805           35.9          5.0              3.2
# 44           22           43.9          1.9              0.8
# 45            2           42.0          1.1              0.3
# 46          250           35.1          4.6              3.1
# 47           93           33.1          2.2              1.4
# 48           27           55.4          3.0              1.5
# 49           97           44.4          2.7              1.7
# 50            5           59.7          1.4              0.9

# %%
# %matplotlib inline
import seaborn as sns
sns.pairplot(guns, size=1.5, aspect=1.5)

# %%
# add variables
# median household income
# median age
# ethnicity (careful with this!)
# education level (how to quantify?)

# %%
import statsmodels.formula.api as smf
lm = smf.ols('murders ~ population', data=guns).fit()
print fit.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7e134cc17e52> in <module>()
#       1 import statsmodels.formula.api as smf
#       2 lm = smf.ols('murders ~ population', data=guns).fit()
# ----> 3 print fit.summary()
#
# NameError: name 'fit' is not defined

# %%
fit = smf.ols('gun_murder_rate ~ population_density', data=guns).fit()
print fit.pvalues
print fit.summary()

# %%
fit = smf.ols('gun_murder_rate ~ gun_ownership', data=guns).fit()
print fit.pvalues
print fit.summary()
# Out:
# Intercept        0.000003
# gun_ownership    0.018741
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        gun_murder_rate   R-squared:                       0.108
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     5.912
# Date:                Tue, 26 May 2015   Prob (F-statistic):             0.0187
# Time:                        18:12:16   Log-Likelihood:                -114.95
# No. Observations:                  51   AIC:                             233.9
# Df Residuals:                      49   BIC:                             237.8
# Df Model:                           1
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         4.9183      0.934      5.268      0.000         3.042     6.794
# gun_ownership    -0.0575      0.024     -2.431      0.019        -0.105    -0.010
# ==============================================================================
# Omnibus:                       53.942   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              338.167
# Skew:                           2.678   Prob(JB):                     3.70e-74
# Kurtosis:                      14.422   Cond. No.                         112.
# ==============================================================================

# %%
fit = smf.ols('gun_murder_rate ~ gun_ownership + population_density', data=guns).fit()
print fit.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        gun_murder_rate   R-squared:                       0.639
# Model:                            OLS   Adj. R-squared:                  0.624
# Method:                 Least Squares   F-statistic:                     42.43
# Date:                Tue, 26 May 2015   Prob (F-statistic):           2.44e-11
# Time:                        18:10:48   Log-Likelihood:                -91.888
# No. Observations:                  51   AIC:                             189.8
# Df Residuals:                      48   BIC:                             195.6
# Df Model:                           2
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept              1.9310      0.698      2.768      0.008         0.528     3.334
# gun_ownership          0.0084      0.017      0.489      0.627        -0.026     0.043
# population_density     0.0014      0.000      8.400      0.000         0.001     0.002
# ==============================================================================
# Omnibus:                       10.469   Durbin-Watson:                   2.448
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               10.550
# Skew:                           0.875   Prob(JB):                      0.00512
# Kurtosis:                       4.379   Cond. No.                     4.87e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 4.87e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
fit = smf.ols('murder_rate ~ population_density', data=guns).fit()
print fit.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            murder_rate   R-squared:                       0.649
# Model:                            OLS   Adj. R-squared:                  0.641
# Method:                 Least Squares   F-statistic:                     90.44
# Date:                Tue, 26 May 2015   Prob (F-statistic):           1.04e-12
# Time:                        18:07:45   Log-Likelihood:                -103.38
# No. Observations:                  51   AIC:                             210.8
# Df Residuals:                      49   BIC:                             214.6
# Df Model:                           1
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept              3.5005      0.272     12.855      0.000         2.953     4.048
# population_density     0.0018      0.000      9.510      0.000         0.001     0.002
# ==============================================================================
# Omnibus:                        4.027   Durbin-Watson:                   2.395
# Prob(Omnibus):                  0.134   Jarque-Bera (JB):                3.171
# Skew:                           0.597   Prob(JB):                        0.205
# Kurtosis:                       3.255   Cond. No.                     1.53e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.53e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import sklearn.linear_model as linear_model
import numpy as np
import matplotlib.pyplot as plt

def fit_and_plot(x, y, xlim):
    
    # Create linear regression object
    regr = linear_model.LinearRegression()
    regr.fit(x, y)
    print "residuals", regr.residues_
    print "Coefficients: \n", regr.coef_

    # The mean square error
    print("Residual sum of squares: %.2f" % np.mean((regr.predict(x) - y) ** 2))
    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % regr.score(x, y))
    print "intercept", regr.intercept_

    plt.scatter(x, y, color='black', s=1)
    plt.plot(x, regr.predict(x), color='blue', linewidth=3)
    plt.xlim(xlim)
    plt.show()

# %%
x = guns['population_density'].values.reshape(-1,1)
y = guns['gun_murder_rate'].values

fit_and_plot(x, y, (0, 2000))
# Out:
# residuals 110.209072338
# Coefficients:
# [ 0.00136751]
# Residual sum of squares: 2.16
# Variance score: 0.64
# intercept 2.2545665529

# %%
x = guns['gun_ownership'].values.reshape(-1,1)
y = guns['gun_murder_rate'].values

fit_and_plot(x, y, (0, 100))
# Out:
# residuals 270.867654146
# Coefficients:
# [-0.0574961]
# Residual sum of squares: 5.31
# Variance score: 0.11
# intercept 4.91831675272

# %%
x = guns['population_density'].values.reshape(-1,1)
y = guns['gun_murder_rate'].values

fit_and_plot(x, y, (0, 500))
# Out:
# residuals 110.209072338
# Coefficients:
# [ 0.00136751]
# Residual sum of squares: 2.16
# Variance score: 0.64
# intercept 2.2545665529

# %%
# throw out DC because it is an extreme outlier
# box plot to find outliers
#
